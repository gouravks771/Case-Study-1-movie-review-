# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mv=pd.read_csv("/content/Movie+Assignment+Data.csv.csv")
mv
# Out:
#                                            Title  ...    Country
# 0                                     La La Land  ...        USA
# 1                                       Zootopia  ...        USA
# 2                                           Lion  ...  Australia
# 3                                        Arrival  ...        USA
# 4                          Manchester by the Sea  ...        USA
# ..                                           ...  ...        ...
# 95                                      Whiplash  ...        USA
# 96                               Before Midnight  ...        USA
# 97    Star Wars: Episode VII - The Force Awakens  ...        USA
# 98  Harry Potter and the Deathly Hallows: Part I  ...         UK
# 99                       Tucker and Dale vs Evil  ...     Canada
#
# [100 rows x 62 columns]

# %%
mv['budget']=mv['budget']/1000000
mv
# Out:
#                                            Title  ...    Country
# 0                                     La La Land  ...        USA
# 1                                       Zootopia  ...        USA
# 2                                           Lion  ...  Australia
# 3                                        Arrival  ...        USA
# 4                          Manchester by the Sea  ...        USA
# ..                                           ...  ...        ...
# 95                                      Whiplash  ...        USA
# 96                               Before Midnight  ...        USA
# 97    Star Wars: Episode VII - The Force Awakens  ...        USA
# 98  Harry Potter and the Deathly Hallows: Part I  ...         UK
# 99                       Tucker and Dale vs Evil  ...     Canada
#
# [100 rows x 62 columns]

# %%
mv["Gross"]=mv['Gross']/1000000

# %%
mv['profit']=mv['Gross']-mv['budget']
mv
# Out:
#                                            Title  ...      profit
# 0                                     La La Land  ...  121.101803
# 1                                       Zootopia  ...  191.268248
# 2                                           Lion  ...   39.738905
# 3                                        Arrival  ...   53.546139
# 4                          Manchester by the Sea  ...   38.695371
# ..                                           ...  ...         ...
# 95                                      Whiplash  ...    9.792000
# 96                               Before Midnight  ...    5.114507
# 97    Star Wars: Episode VII - The Force Awakens  ...  691.662225
# 98  Harry Potter and the Deathly Hallows: Part I  ...  146.347721
# 99                       Tucker and Dale vs Evil  ...   -4.776162
#
# [100 rows x 63 columns]

# %%
mv=mv.sort_values(by="profit",ascending=False)

# %%
mv.iloc[:10,:]
# Out:
#                                          Title  ...      profit
# 97  Star Wars: Episode VII - The Force Awakens  ...  691.662225
# 11                                The Avengers  ...  403.279547
# 47                                    Deadpool  ...  305.024263
# 32             The Hunger Games: Catching Fire  ...  294.645577
# 12                                 Toy Story 3  ...  214.984497
# 8                        The Dark Knight Rises  ...  198.130642
# 45                              The Lego Movie  ...  197.756197
# 1                                     Zootopia  ...  191.268248
# 41                               Despicable Me  ...  182.501645
# 18                                  Inside Out  ...  181.454367
#
# [10 rows x 63 columns]

# %%
sns.jointplot("budget","profit",mv)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
mv[mv['profit']<0]
# Out:
#                           Title  title_year  ...  Country     profit
# 99      Tucker and Dale vs Evil        2010  ...   Canada  -4.776162
# 89                        Amour        2012  ...   France  -8.674623
# 56                         Rush        2013  ...       UK -11.096291
# 66                      Warrior        2011  ...      USA -11.348338
# 82                      Flipped        2010  ...      USA -12.247786
# 28           X-Men: First Class        2011  ...      USA -13.594629
# 46  Scott Pilgrim vs. the World        2010  ...      USA -28.505730
# 7                       Tangled        2010  ...      USA -59.192738
# 17             Edge of Tomorrow        2014  ...      USA -77.810499
# 39            The Little Prince        2015  ...   France -79.860848
# 22                         Hugo        2011  ...      USA -96.179906
#
# [11 rows x 63 columns]

# %%
mv['MetaCritic']=mv['MetaCritic']/10

# %%
mv['Avg_Rating']=(mv["IMDb_rating"]+mv['MetaCritic'])/2

# %%
df=mv[["Title",'IMDb_rating',"MetaCritic",'Avg_Rating']]
df=df.loc[abs(df['IMDb_rating']-df['MetaCritic']<0.5)]

# %%
df=df.sort_values(by="Avg_Rating",ascending=False)
UniversalAclaimed=df.loc[df['Avg_Rating']>=8]
UniversalAclaimed
# Out:
#                                               Title  ...  Avg_Rating
# 94                                          Boyhood  ...        8.95
# 69                                 12 Years a Slave  ...        8.85
# 18                                       Inside Out  ...        8.80
# 12                                      Toy Story 3  ...        8.75
# 0                                        La La Land  ...        8.75
# 4                             Manchester by the Sea  ...        8.75
# 70                                        Spotlight  ...        8.70
# 34                                          Gravity  ...        8.70
# 96                                  Before Midnight  ...        8.65
# 89                                            Amour  ...        8.65
# 95                                         Whiplash  ...        8.65
# 53                               The Social Network  ...        8.60
# 29                               Mad Max: Fury Road  ...        8.55
# ...

# %%
group =mv.pivot_table(values=['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes'],
               aggfunc='sum',index=['actor_1_name','actor_2_name','actor_3_name'])

# %%
group['Total_likes']=group['actor_1_facebook_likes']+group['actor_2_facebook_likes']+group['actor_3_facebook_likes']

# %%
group.sort_values(by='Total_likes',ascending=False,inplace=True)

# %%
group
# Out:
#                                                                     actor_1_facebook_likes  ...  Total_likes
# actor_1_name             actor_2_name       actor_3_name                                    ...
# Dev Patel                Nicole Kidman      Rooney Mara                              33000  ...     138800.0
# Leonardo DiCaprio        Tom Hardy          Joseph Gordon-Levitt                     29000  ...      79000.0
# Jennifer Lawrence        Peter Dinklage     Hugh Jackman                             34000  ...      76000.0
# Casey Affleck            Michelle Williams  Kyle Chandler                              518  ...      74818.0
# Tom Hardy                Christian Bale     Joseph Gordon-Levitt                     27000  ...      73000.0
# ...                                                                                    ...  ...          ...
# Ellar Coltrane           Lorelei Linklater  Libby Villari                              230  ...        550.0
# ...

# %%
group.reset_index(inplace=True)
group
# Out:
#                 actor_1_name  ... Total_likes
# 0                  Dev Patel  ...    138800.0
# 1          Leonardo DiCaprio  ...     79000.0
# 2          Jennifer Lawrence  ...     76000.0
# 3              Casey Affleck  ...     74818.0
# 4                  Tom Hardy  ...     73000.0
# ..                       ...  ...         ...
# 94            Ellar Coltrane  ...       550.0
# 95             Elina Alminas  ...       417.0
# 96  Seamus Davey-Fitzpatrick  ...       251.0
# 97               Doug Walker  ...       143.0
# 98            Phaldut Sharma  ...        75.0
#
# [99 rows x 7 columns]

# %%
group=group.iloc[0:5,:]

# %%
group
# Out:
#         actor_1_name        actor_2_name  ... actor_3_facebook_likes  Total_likes
# 0          Dev Patel       Nicole Kidman  ...                 9800.0     138800.0
# 1  Leonardo DiCaprio           Tom Hardy  ...                23000.0      79000.0
# 2  Jennifer Lawrence      Peter Dinklage  ...                20000.0      76000.0
# 3      Casey Affleck  Michelle Williams   ...                 3300.0      74818.0
# 4          Tom Hardy      Christian Bale  ...                23000.0      73000.0
#
# [5 rows x 7 columns]

# %%
j=0
for i in group['Total_likes']:
  temp=sorted([group.loc[j,'actor_1_facebook_likes'],group.loc[j,'actor_2_facebook_likes'],group.loc[j,'actor_3_facebook_likes']])
  if temp[0]>=temp[1]/2 and temp[0]>=temp[2]/2 and temp[1]>=temp[2]/2 :
    print(sorted([group.loc[j,'actor_1_name'],group.loc[j,'actor_2_name'],group.loc[j,'actor_1_name']]))

  j=j+1
# Out:
# ['Leonardo DiCaprio', 'Leonardo DiCaprio', 'Tom Hardy']
# ['Jennifer Lawrence', 'Jennifer Lawrence', 'Peter Dinklage']
# ['Christian Bale', 'Tom Hardy', 'Tom Hardy']

# %%
plt.hist(mv['Runtime'])
plt.show()

# %%
mv.loc[mv['content_rating']=="R"].sort_values(by='CVotesU18',ascending=False)[['Title','CVotesU18']].head(10)
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891

# %%
df_by_genre=mv.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]]=mv[["genre_1","genre_2","genre_3"]]
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  ...    genre_1    genre_2  genre_3
# 97    155391    161810    166378  ...     Action  Adventure  Fantasy
# 11    260257    234203    264290  ...     Action     Sci-Fi      NaN
# 47    147467    147966    170810  ...     Action  Adventure   Comedy
# 32     85219     83874    150153  ...     Action  Adventure  Mystery
# 12    139773    149992    158704  ...  Animation  Adventure   Comedy
# ..       ...       ...       ...  ...        ...        ...      ...
# 46     47292     48976     79198  ...     Action     Comedy  Romance
# 7      56575     54688     97207  ...  Animation  Adventure   Comedy
# 17     60383     99596    175961  ...     Action  Adventure   Sci-Fi
# 39      7565      7321     11668  ...  Animation  Adventure    Drama
# 22     29228     40728     77893  ...  Adventure      Drama   Family
#
# [100 rows x 47 columns]

# %%
#ADD a column cnt and put value 1
df_by_genre['cnt']=1
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  ...    genre_1    genre_2  genre_3  cnt
# 97    155391    161810    166378     99402  ...     Action  Adventure  Fantasy    1
# 11    260257    234203    264290    162604  ...     Action     Sci-Fi      NaN    1
# 47    147467    147966    170810    105717  ...     Action  Adventure   Comedy    1
# 32     85219     83874    150153    121748  ...     Action  Adventure  Mystery    1
# 12    139773    149992    158704     88289  ...  Animation  Adventure   Comedy    1
# ..       ...       ...       ...       ...  ...        ...        ...      ...  ...
# 46     47292     48976     79198     59689  ...     Action     Comedy  Romance    1
# 7      56575     54688     97207     70947  ...  Animation  Adventure   Comedy    1
# 17     60383     99596    175961    100724  ...     Action  Adventure   Sci-Fi    1
# 39      7565      7321     11668      8558  ...  Animation  Adventure    Drama    1
# ...

# %%
df_by_g1=df_by_genre.groupby("genre_1").aggregate(np.sum)
df_by_g2=df_by_genre.groupby("genre_2").aggregate(np.sum)
df_by_g3=df_by_genre.groupby("genre_3").aggregate(np.sum)

# %%
df_add=df_by_g1.add(df_by_g2,fill_value=0)

# %%
df_add=df_add.add(df_by_g3,fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08  ...  VotesUS  VotesnUS   cnt
# Action     3166467.0  3547429.0  4677755.0  ...    247.6     240.6  31.0
# Adventure  3594659.0  4014192.0  5262328.0  ...    303.5     296.2  38.0
# Animation   681562.0   798227.0  1153214.0  ...     87.6      86.1  11.0
# Biography   852003.0  1401608.0  2231078.0  ...    142.7     139.9  18.0
# Comedy     1383616.0  1774987.0  2506851.0  ...    182.6     178.9  23.0
# Crime       574526.0   967118.0  1419495.0  ...     87.8      85.8  11.0
# Drama      3404438.0  4935375.0  7107053.0  ...    515.9     506.0  65.0
# Family       98165.0    95675.0   180381.0  ...     15.6      15.0   2.0
# Fantasy     572452.0   602223.0   889767.0  ...     54.9      53.7   7.0
# History     151261.0   260387.0   394531.0  ...     32.2      31.2   4.0
# Horror       16572.0    19818.0    44460.0  ...      7.7       7.5   1.0
# Music       184649.0   233055.0   197296.0  ...     16.9      16.5   2.0
# ...

# %%
genre_top10=df_add.loc[df_add['cnt']>10]
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08  ...  VotesUS  VotesnUS   cnt
# Action     3166467.0  3547429.0  4677755.0  ...    247.6     240.6  31.0
# Adventure  3594659.0  4014192.0  5262328.0  ...    303.5     296.2  38.0
# Animation   681562.0   798227.0  1153214.0  ...     87.6      86.1  11.0
# Biography   852003.0  1401608.0  2231078.0  ...    142.7     139.9  18.0
# Comedy     1383616.0  1774987.0  2506851.0  ...    182.6     178.9  23.0
# Crime       574526.0   967118.0  1419495.0  ...     87.8      85.8  11.0
# Drama      3404438.0  4935375.0  7107053.0  ...    515.9     506.0  65.0
# Romance     549959.0   689492.0  1069280.0  ...    101.8     100.1  13.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  ...    137.5     134.0  17.0
# Thriller   1081701.0  1465491.0  1993378.0  ...    103.1     101.5  13.0
#
# [10 rows x 45 columns]

# %%
genre_top10.iloc[:,0:-1]=genre_top10.iloc[:,0:-1].divide(genre_top10["cnt"],axis=0)
genre_top10
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 CVotes10       CVotes09  ...  VotesnUS   cnt
# Action     102144.096774  114433.193548  ...  7.761290  31.0
# Adventure   94596.289474  105636.631579  ...  7.794737  38.0
# Animation   61960.181818   72566.090909  ...  7.827273  11.0
# ...

# %%
genre_top10.loc[:,"VotesM":"VotesnUS"]=round(genre_top10.loc[:,"VotesM":"VotesnUS"],2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
genre_top10[genre_top10.loc[:,"CVotes10":"CVotesnUS"].columns]=genre_top10[genre_top10.loc[:,"CVotes10":"CVotesnUS"].columns].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  ...  VotesUS  VotesnUS   cnt
# Action       102144    114433    150895  ...     7.99      7.76  31.0
# Adventure     94596    105636    138482  ...     7.99      7.79  38.0
# Animation     61960     72566    104837  ...     7.96      7.83  11.0
# Biography     47333     77867    123948  ...     7.93      7.77  18.0
# Comedy        60157     77173    108993  ...     7.94      7.78  23.0
# Crime         52229     87919    129045  ...     7.98      7.80  11.0
# Drama         52375     75928    109339  ...     7.94      7.78  65.0
# Romance       42304     53037     82252  ...     7.83      7.70  13.0
# Sci-Fi       136781    148873    176646  ...     8.09      7.88  17.0
# Thriller      83207    112730    153336  ...     7.93      7.81  13.0
#
# [10 rows x 45 columns]

# %%
sns.barplot(x=genre_top10['cnt'],y=genre_top10.index)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
sns.heatmap(genre_top10[['CVotesU18M','CVotes1829M','CVotes3044M','CVotes45AM',]],annot=True,cmap='winter')

plt.subplot(1,2,2)
sns.heatmap(genre_top10[['CVotesU18F','CVotes1829F','CVotes3044F','CVotes45AF',]],annot=True,cmap='winter')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Inferences: A few inferences that can be seen from the heatmap above is that males have voted more than females, and Sci-Fi appears to be most popular among the 18-29 age group irrespective of their gender. What more can you infer from the two heatmaps that you have plotted? Write your three inferences/observations below:
#
# Inference 1: Genre romance has got the least number of votes among any age group of males, but there is no such pattern among the females
# Inference 2:Action seems to be the more popular genre among the under 18 males, and Animation appears to be the most popular genre among under 18 females.
# Inference 3: 18-29 age group seems to be most actively voting for any genre irrespective of gender

# %%
# 2nd set of heat maps for Votes-related columns
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
sns.heatmap(genre_top10[['VotesU18M','Votes1829M','Votes3044M','Votes45AM',]],annot=True,cmap='summer')

plt.subplot(1,2,2)
sns.heatmap(genre_top10[['VotesU18F','Votes1829F','Votes3044F','Votes45AF',]],annot=True,cmap='summer')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Inferences: Sci-Fi appears to be the highest rated genre in the age group of U18 for both males and females. Also, females in this age group have rated it a bit higher than the males in the same age group. What more can you infer from the two heatmaps that you have plotted? Write your three inferences/observations below:
#
# Inference 1:The rating among males, seems to be decreasing with increasing age group . There is similar pattern with female with few exception .
# Inference 2:Crime genre has the second highest rating among U18 age group of both males and males but among U18 female it has got the least rating .
# Inference 3:Romance genre has got the last rating among both 45 above male & female.

# %%
# Creating IFUS column
mv['IFUS']=mv['Country'].copy()

# %%
mv['Country'].value_counts()
# Out:
# USA          81
# UK           11
# Australia     3
# France        3
# Canada        1
# Spain         1
# Name: Country, dtype: int64

# %%
mv.loc[mv['IFUS']!='USA',"IFUS"]='Non-USA'

# %%
mv["IFUS"].value_counts()
# Out:
# USA        81
# Non-USA    19
# Name: IFUS, dtype: int64

# %% [markdown]
# # Box plot - 1: CVotesUS(y) vs IFUS(x)

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
sns.boxplot(x='IFUS',y='CVotesUS',data=mv)

plt.subplot(1,2,2)
sns.boxplot(x='IFUS',y='CVotesnUS',data=mv)

plt.show()

# %% [markdown]
# Inferences: Write your two inferences/observations below:
#
# Inference 1:In general US movies got higher number of  votes from US and Non US voters when compared the median of the box plot .
#
# Inference 2:Non US movies have a more uniform distribution of the number of votes as compared to the US movies .which is evident from the value of the quartiles.

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
sns.boxplot(x='IFUS',y='VotesUS',data=mv)

plt.subplot(1,2,2)
sns.boxplot(x='IFUS',y='VotesnUS',data=mv)

# %% [markdown]
# Inferences: Write your two inferences/observations below:
#
# Inference 1:Non US voters has rated both the US and Non US movies  lower as compared to US voters , which is evident from the medians of box plot .
#
# Inference 2:US movies are received higher ratings by the US voters.
#
# Inference 3:Some US movies got exceptionally high rating from US and Non US voters.There are no such exceptional rating for non US movies.

# %% [markdown]
# # Sorting by CVotes1000

# %%
genre_top10=genre_top10.sort_values('CVotes1000',ascending=False)
genre_top10['CVotes1000']
# Out:
# Sci-Fi       714
# Action       681
# Thriller     669
# Adventure    662
# Crime        620
# Comedy       605
# Biography    600
# Drama        585
# Animation    578
# Romance      548
# Name: CVotes1000, dtype: int64

# %% [markdown]
# # Bar plot

# %%
plt.figure(figsize=(15,10))
sns.barplot(genre_top10.index,genre_top10['CVotes1000'])
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>

# %% [markdown]
# Inference1= The voting pattern almost resembels age group vs genre heat map.
#
# Inference2= Although Drama genre has the highest number movies , the average number of top users who have it as less as compared to other genre which has less number movies in there.
